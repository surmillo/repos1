# %% [markdown]
# # PYTHON. SEM1. 🧑‍💻

# %% [markdown]
# ## **Математические операции:**

# %%
print(a, sep="", end='\n')
sep='' - разделитель
end='' - конец строки
\n - перевод на новую строку
a%b - остаток
a**b - возведение в степень 
a//b - взятие целой части
min(a,b, ...) - минимум чисел
max(a,b, ...) - минимум чисел
abs(a) - модуль
pow(a,b) - возведение в степень 
round(a) - округление чисел к ближайшему целому

# %%
input('...') - ввод данных из терминала.

# %% [markdown]
# **Переменные** - ячейка в памяти, куда можно заносить информацию и затем на нее ссылаться.
#
# **Основные типы данных в Python** (это далеко не конец!):
# - int - целые числа
# - float - вещественные числа
# - str - строки

# %% [markdown]
# ## Задание 1. Вывести всё.

# %% [markdown]
# - Написать программу для пересчёта величины временного интервала, заданного в минутах, в величину, выраженную в часах и минутах по образцу.

# %%
In[1]: 150
Out[1]: 150 минут - это 2 час 30 минут.

# %% [markdown]
# - Написать программу, последовательно считатывающую три строки и выводящую их в одну строку в обратном порядке по образцу.

# %%
In[1]: Python 
In[2]: love
In[3]: I
Out[1]: I!love!Python!

# %% [markdown]
# ## Задание 2. Решение квадратного уравнения.

# %% [markdown]
# Реализовать программу, принимающую на вход три числа: **a**, **b**, **с**, соответствующие коэффициентам в квадратном уравнении $ax^2 + bx + c$. Вывести корни уравнения в порядке их *убывания*.

# %%
In[1]: -6
In[2]: 0
In[3]: 54
Out[1]: x1 = 3, x2 = -3

# %% [markdown]
# ## Задание 3. Ввод формулы😭.

# %% [markdown]
# Реализовать программу, принимающую на вход температуру **T** и частоту **$\nu$** и рассчитывающую значение плотность распределения энергии излучения.
# > Нужно обратить внимание на размерности физических величин!

# %%
from IPython.display import Image 
display(Image(filename='1 задание.png', width = 500))

# %% [markdown]
# ## Задание 4. Трехзначное число.

# %% [markdown]
# - Написать программу, в которой рассчитывается сумма и произведение цифр положительного трёхзначного числа по образцу.

# %%
In[1]: 123
Out[1]: Сумма цифр = 6
Произведение цифр = 6

In[1]: 999
Out[1]: Сумма цифр = 27
Произведение цифр = 729

# %% [markdown]
# ## Задание 5. Перестановка цифр.

# %% [markdown]
# Дано трехзначное число abc, в котором все цифры различны. Написать программу, которая выводит 6 чисел, образованных при перестановке цифр заданного числа.
#
# **Формат выходных данных:**
# Программа должна выводить числа в последовательности abc, acb, bac, bca, cab, cba.

# %%
In[1]: 123
Out[1]: 
    123
    132
    213
    231
    312
    321
